# %% [markdown]
# ## 讀取圖片
# 常見的套件:
# 1. skimage
# 2. PIL
# 3. OpenCV

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import skimage.io as skio
img1 = skio.imread('Part01/example.jpg')
plt.imshow(img1)
plt.show()

# %%
from PIL import Image
img2 = Image.open('Part01/example.jpg') # 這時候還是 PIL object
img2 = np.array(img2)
plt.imshow(img2)
plt.show()

# %%
import cv2
img3 = cv2.imread('Part01/example.jpg')
plt.imshow(img3)
plt.show()

img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
plt.imshow(img3)
plt.show()

# %% [markdown]
# ### 比較三種開圖方式的時間 - 比較讀取 1000 次

# %%
N_times = 1

# %%
# %%timeit
im = np.array([skio.imread('Part01/example.jpg') for _ in range(N_times)])
# Out:
# 7.59 ms ± 71.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
im = np.array([np.array(Image.open('Part01/example.jpg')) for _ in range(N_times)])
# Out:
# 7.23 ms ± 362 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
im = np.array([cv2.cvtColor(cv2.imread('Part01/example.jpg'), cv2.COLOR_BGR2RGB) for _ in range(N_times)])
# Out:
# 11.5 ms ± 216 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## 將影像存成 mat

# %%
import scipy.io as sio
sio.savemat(file_name='Part01/example.mat', mdict={'img': img1})

# %%
mat_arr = sio.loadmat('Part01/example.mat')
print(mat_arr.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'img'])

# %%
mat_arr
# Out:
# {'__globals__': [],
#  '__header__': b'MATLAB 5.0 MAT-file Platform: nt, Created on: Thu Apr 18 00:37:13 2019',
#  '__version__': '1.0',
#  'img': array([[[204, 194, 184],
#          [204, 194, 184],
#          [204, 194, 184],
#          ...,
#          [224, 210, 201],
#          [224, 210, 201],
#          [224, 210, 201]],
#
#         [[204, 194, 184],
#          [204, 194, 184],
#          [204, 194, 184],
#          ...,
#          [224, 210, 201],
#          [224, 210, 201],
#          [224, 210, 201]],
#
#         [[204, 194, 184],
#          [204, 194, 184],
#          [204, 194, 184],
#          ...,
#          [225, 211, 202],
#          [225, 211, 202],
#          [225, 211, 202]],
#
#         ...,
#
#         [[146, 140, 140],
#          [172, 166, 166],
#          [160, 154, 154],
#          ...,
#          [  3,   2,   0],
#          [  3,   2,   0],
#          [  3,   2,   0]],
#
#         [[112, 106, 106],
#          [157, 151, 151],
#          [162, 156, 156],
# ...

# %%
mat_arr = mat_arr['img']
print(mat_arr.shape)
# Out:
# (813, 771, 3)

# %%
plt.imshow(mat_arr)
plt.show()

# %% [markdown]
# # 練習時間
#
# ## 1-1 讀取 txt 檔
# * 請讀取 [text file](https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt)
# * 懶人複製連結: https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt
#
# ## 1-2 將所提供的 txt 轉成 pandas dataframe
#
# ## 2. 從所提供的 txt 中的連結讀取圖片，請讀取上面 data frame 中的前 5 張圖片
